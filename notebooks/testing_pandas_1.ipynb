# %%
import pandas as pd

# %%
df = pd.read_csv("../__datasets/baseball/fangraphs-leaderboard-players-at-bat.csv", nrows = 100)

# %%
df.head()
# Out:
#                Name     Team    G   PA  HR    R  RBI  SB     BB%      K%  ...  \
# 0      Mookie Betts  Red Sox  136  614  32  129   80  30  13.2 %  14.8 %  ...
# 1        Mike Trout   Angels  140  608  39  101   79  24  20.1 %  20.4 %  ...
# 2      Jose Ramirez  Indians  157  698  39  110  105  34  15.2 %  11.5 %  ...
# 3      Alex Bregman   Astros  157  705  31  105  103  10  13.6 %  12.1 %  ...
# 4  Francisco Lindor  Indians  158  745  38  129   92  25   9.4 %  14.4 %  ...
#
#      AVG    OBP    SLG   wOBA  wRC+   BsR   Off   Def   WAR  playerid
# 0  0.346  0.438  0.640  0.449   185   6.9  69.1  11.6  10.4     13611
# 1  0.312  0.460  0.628  0.447   191   5.0  71.1   4.2   9.8     10155
# 2  0.270  0.387  0.552  0.391   146  12.0  50.6   4.6   8.0     13510
# 3  0.286  0.394  0.532  0.396   157   3.4  51.4  -0.6   7.6     17678
# 4  0.277  0.352  0.519  0.368   130   1.2  28.3  21.1   7.6     12916
#
# [5 rows x 22 columns]

# %%
df.tail()
# Out:
#                 Name       Team    G   PA  HR   R  RBI  SB     BB%      K%  \
# 95   Jonathan Villar      - - -  141  515  14  54   46  35   8.0 %  26.8 %
# 96      Tim Anderson  White Sox  153  606  20  77   64  26   5.0 %  24.6 %
# 97    Carlos Santana   Phillies  161  679  24  82   86   2  16.2 %  13.7 %
# 98  Brandon Crawford     Giants  151  594  14  63   54   4   8.4 %  20.5 %
# 99    Dansby Swanson     Braves  136  533  14  51   59  10   8.3 %  22.9 %
#
#     ...    AVG    OBP    SLG   wOBA  wRC+  BsR   Off   Def  WAR  playerid
# 95  ...  0.260  0.325  0.384  0.312    94  3.3  -0.5   3.6  2.0     10071
# 96  ...  0.240  0.281  0.406  0.294    85  2.8  -7.9   7.2  2.0     15172
# 97  ...  0.229  0.352  0.414  0.333   109 -0.1   7.2  -9.9  1.9      2396
# 98  ...  0.254  0.325  0.394  0.306    93 -0.8  -5.8   5.5  1.9      5343
# 99  ...  0.238  0.304  0.395  0.293    80  3.1 -10.1  11.3  1.8     18314
#
# [5 rows x 22 columns]

# %%
df = df.sample(frac = 1)

# %%
df
# Out:
#                  Name          Team    G   PA  HR    R  RBI  SB     BB%  \
# 89    Cesar Hernandez      Phillies  161  708  15   91   60  19  13.4 %
# 33     Eugenio Suarez          Reds  143  606  34   79  104   1  10.6 %
# 30  Andrew Benintendi       Red Sox  148  661  16  103   87  21  10.7 %
# 77    Gregory Polanco       Pirates  130  535  23   75   81  12  11.4 %
# 49         Matt Olson     Athletics  162  660  29   85   84   2  10.6 %
# 39     Starling Marte       Pirates  145  606  20   81   72  33   5.8 %
# 22        Aaron Hicks       Yankees  137  581  27   90   79  11  15.5 %
# 58   Michael Conforto          Mets  153  638  28   78   82   3  13.2 %
# 96       Tim Anderson     White Sox  153  606  20   77   64  26   5.0 %
# 4    Francisco Lindor       Indians  158  745  38  129   92  25   9.4 %
# 60     Ender Inciarte        Braves  156  660  10   83   61  28   7.4 %
# 54       Chris Taylor       Dodgers  155  604  17   85   63   9   9.1 %
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Team', 'G', 'PA', 'HR', 'R', 'RBI', 'SB', 'BB%', 'K%', 'ISO',
#        'BABIP', 'AVG', 'OBP', 'SLG', 'wOBA', 'wRC+', 'BsR', 'Off', 'Def',
#        'WAR', 'playerid'],
#       dtype='object')

# %%
df.HR
# Out:
# 89    15
# 33    34
# 30    16
# 77    23
# 49    29
# 39    20
# 22    27
# 58    28
# 96    20
# 4     38
# 60    10
# 54    17
# 99    14
# 31    38
# 23    23
# 81    12
# 57    27
# 72    20
# 71    23
# 37     7
# 78    19
# 38    15
# 14    23
# 48     2
# 65    40
# 43    12
# 95    14
# 80    14
# 67    13
# 74    20
#       ..
# 68    23
# 35    10
# 15    12
# 45    34
# 1     39
# 73    48
# 26    27
# 28    17
# 6     24
# 70    27
# 24    21
# 86    12
# 5     36
# 10    38
# 50    24
# 53    30
# 44    17
# 29    23
# 84    21
# 98    14
# 2     39
# 41    25
# 32    21
# 52    26
# 87    20
# 97    24
# 7     37
# 36    24
# 75    14
# 34    30
# Name: HR, Length: 100, dtype: int64

# %%
df.dtypes
# Out:
# Name         object
# Team         object
# G             int64
# PA            int64
# HR            int64
# R             int64
# RBI           int64
# SB            int64
# BB%          object
# K%           object
# ISO         float64
# BABIP       float64
# AVG         float64
# OBP         float64
# SLG         float64
# wOBA        float64
# wRC+          int64
# BsR         float64
# Off         float64
# Def         float64
# WAR         float64
# playerid      int64
# dtype: object

# %%
df.values
# Out:
# array([['Cesar Hernandez', 'Phillies', 161, ..., -0.9, 2.2, 10556],
#        ['Eugenio Suarez', 'Reds', 143, ..., -2.9, 3.9, 12552],
#        ['Andrew Benintendi', 'Red Sox', 148, ..., -1.5, 4.4, 17901],
#        ...,
#        ['Ozzie Albies', 'Braves', 158, ..., 9.0, 3.8, 16556],
#        ['Nick Markakis', 'Braves', 162, ..., -6.4, 2.6, 5930],
#        ['David Peralta', 'Diamondbacks', 146, ..., -4.9, 3.8, 2136]],
#       dtype=object)

# %%
df2 = df.head(10)

# %%
df2.head(20)
# Out:
#                  Name       Team    G   PA  HR    R  RBI  SB     BB%      K%  \
# 89    Cesar Hernandez   Phillies  161  708  15   91   60  19  13.4 %  21.9 %
# 33     Eugenio Suarez       Reds  143  606  34   79  104   1  10.6 %  23.4 %
# 30  Andrew Benintendi    Red Sox  148  661  16  103   87  21  10.7 %  16.0 %
# 77    Gregory Polanco    Pirates  130  535  23   75   81  12  11.4 %  21.9 %
# 49         Matt Olson  Athletics  162  660  29   85   84   2  10.6 %  24.7 %
# 39     Starling Marte    Pirates  145  606  20   81   72  33   5.8 %  18.0 %
# 22        Aaron Hicks    Yankees  137  581  27   90   79  11  15.5 %  19.1 %
# 58   Michael Conforto       Mets  153  638  28   78   82   3  13.2 %  24.9 %
# 96       Tim Anderson  White Sox  153  606  20   77   64  26   5.0 %  24.6 %
# 4    Francisco Lindor    Indians  158  745  38  129   92  25   9.4 %  14.4 %
#
#     ...    AVG    OBP    SLG   wOBA  wRC+  BsR   Off   Def  WAR  playerid
# ...

# %%
df["HR"].head()
# Out:
# 89    15
# 33    34
# 30    16
# 77    23
# 49    29
# Name: HR, dtype: int64

# %%
df[0:10]
# Out:
#                  Name       Team    G   PA  HR    R  RBI  SB     BB%      K%  \
# 89    Cesar Hernandez   Phillies  161  708  15   91   60  19  13.4 %  21.9 %
# 33     Eugenio Suarez       Reds  143  606  34   79  104   1  10.6 %  23.4 %
# 30  Andrew Benintendi    Red Sox  148  661  16  103   87  21  10.7 %  16.0 %
# 77    Gregory Polanco    Pirates  130  535  23   75   81  12  11.4 %  21.9 %
# 49         Matt Olson  Athletics  162  660  29   85   84   2  10.6 %  24.7 %
# 39     Starling Marte    Pirates  145  606  20   81   72  33   5.8 %  18.0 %
# 22        Aaron Hicks    Yankees  137  581  27   90   79  11  15.5 %  19.1 %
# 58   Michael Conforto       Mets  153  638  28   78   82   3  13.2 %  24.9 %
# 96       Tim Anderson  White Sox  153  606  20   77   64  26   5.0 %  24.6 %
# 4    Francisco Lindor    Indians  158  745  38  129   92  25   9.4 %  14.4 %
#
#     ...    AVG    OBP    SLG   wOBA  wRC+  BsR   Off   Def  WAR  playerid
# ...

# %%
df[df["HR"] > 40]
# Out:
#              Name       Team    G   PA  HR    R  RBI  SB     BB%      K%  ...  \
# 9   J.D. Martinez    Red Sox  150  649  43  111  130   6  10.6 %  22.5 %  ...
# 73    Khris Davis  Athletics  151  654  48   98  123   0   9.0 %  26.8 %  ...
#
#       AVG    OBP    SLG   wOBA  wRC+  BsR   Off   Def  WAR  playerid
# 9   0.330  0.402  0.629  0.427   170 -4.1  50.3 -14.7  5.9      6184
# 73  0.247  0.326  0.549  0.365   135 -4.8  22.2 -18.5  2.6      9112
#
# [2 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['Name', 'Team', 'G', 'PA', 'HR', 'R', 'RBI', 'SB', 'BB%', 'K%', 'ISO',
#        'BABIP', 'AVG', 'OBP', 'SLG', 'wOBA', 'wRC+', 'BsR', 'Off', 'Def',
#        'WAR', 'playerid'],
#       dtype='object')

# %%
df[(df["HR"] >= 30) & (df["SB"] >= 30)]
# Out:
#            Name     Team    G   PA  HR    R  RBI  SB     BB%      K%  ...  \
# 0  Mookie Betts  Red Sox  136  614  32  129   80  30  13.2 %  14.8 %  ...
# 2  Jose Ramirez  Indians  157  698  39  110  105  34  15.2 %  11.5 %  ...
#
#      AVG    OBP    SLG   wOBA  wRC+   BsR   Off   Def   WAR  playerid
# 0  0.346  0.438  0.640  0.449   185   6.9  69.1  11.6  10.4     13611
# 2  0.270  0.387  0.552  0.391   146  12.0  50.6   4.6   8.0     13510
#
# [2 rows x 22 columns]

# %%
df.HR
# Out:
# 89    15
# 33    34
# 30    16
# 77    23
# 49    29
# 39    20
# 22    27
# 58    28
# 96    20
# 4     38
# 60    10
# 54    17
# 99    14
# 31    38
# 23    23
# 81    12
# 57    27
# 72    20
# 71    23
# 37     7
# 78    19
# 38    15
# 14    23
# 48     2
# 65    40
# 43    12
# 95    14
# 80    14
# 67    13
# 74    20
#       ..
# 68    23
# 35    10
# 15    12
# 45    34
# 1     39
# 73    48
# 26    27
# 28    17
# 6     24
# 70    27
# 24    21
# 86    12
# 5     36
# 10    38
# 50    24
# 53    30
# 44    17
# 29    23
# 84    21
# 98    14
# 2     39
# 41    25
# 32    21
# 52    26
# 87    20
# 97    24
# 7     37
# 36    24
# 75    14
# 34    30
# Name: HR, Length: 100, dtype: int64

# %%
df.groupby(by = "Team")["HR"].describe()
# Out:
#               count       mean        std   min    25%   50%    75%   max
# Team
# - - -           8.0  22.500000   7.502381  14.0  18.50  22.0  24.25  37.0
# Angels          3.0  26.666667  14.294521  11.0  20.50  30.0  34.50  39.0
# Astros          3.0  22.000000   9.000000  13.0  17.50  22.0  26.50  31.0
# Athletics       6.0  27.666667  11.057426  15.0  23.25  25.5  28.50  48.0
# Blue Jays       1.0  15.000000        NaN  15.0  15.00  15.0  15.00  15.0
# Braves          6.0  17.333333   5.573748  10.0  14.00  16.5  22.00  24.0
# Brewers         4.0  28.250000  12.284814  10.0  26.50  33.5  35.25  36.0
# Cardinals       4.0  24.000000   8.366600  17.0  19.25  21.5  26.25  36.0
# Cubs            4.0  23.500000  10.472185   9.0  21.00  25.5  28.00  34.0
# Diamondbacks    3.0  25.666667  10.214369  14.0  22.00  30.0  31.50  33.0
# Dodgers         3.0  22.000000   4.358899  17.0  20.50  24.0  24.50  25.0
# Giants          1.0  14.000000        NaN  14.0  14.00  14.0  14.00  14.0
# ...

# %%
df.groupby(by = "Team")["HR","SB"].mean()
# Out:
#                      HR         SB
# Team
# - - -         22.500000  12.500000
# Angels        26.666667  14.000000
# Astros        22.000000  11.000000
# Athletics     27.666667   3.166667
# Blue Jays     15.000000  14.000000
# Braves        17.333333  10.666667
# Brewers       28.250000  14.250000
# Cardinals     24.000000   2.750000
# Cubs          23.500000   8.500000
# Diamondbacks  25.666667   5.666667
# Dodgers       22.000000   8.333333
# Giants        14.000000   4.000000
# Indians       28.000000  19.500000
# Mariners      24.333333   9.666667
# Marlins       14.666667   3.666667
# Mets          22.500000   6.000000
# Nationals     25.666667  19.333333
# Phillies      24.333333   8.666667
# Pirates       18.666667  17.666667
# Rangers       24.750000   7.750000
# Rays          10.750000  17.250000
# Red Sox       25.400000  16.400000
# Reds          20.750000   7.500000
# Rockies       29.750000  11.750000
# Royals        12.000000  45.000000
# ...
